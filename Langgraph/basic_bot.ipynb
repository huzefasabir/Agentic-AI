# %% [markdown]
# Build a Basic chatbot woth Langgraph

# %%
# !pip install langgraph
# Out:
# Collecting langgraph
#   Downloading langgraph-1.2.9-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2,>=1.4.7 (from langgraph)
#   Downloading langchain_core-1.5.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting pydantic>=2.7.4 (from langgraph)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.8.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2,>=1.4.7->langgraph)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2,>=1.4.7->langgraph)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2,>=1.4.7->langgraph)
#   Downloading langsmith-0.10.10-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\huzef\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (26.2)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2,>=1.4.7->langgraph)
#   Downloading pyyaml-6.0.3-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2,>=1.4.7->langgraph)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\huzef\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2,>=1.4.7->langgraph)
#   Downloading uuid_utils-0.17.0-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph)
#   Downloading jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph)
#   Downloading ormsgpack-1.12.2-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph)
#   Downloading orjson-3.11.9-cp310-cp310-win_amd64.whl.metadata (43 kB)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph)
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Collecting anyio>=3.5.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph)
#   Downloading anyio-4.14.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro>=1.7.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\huzef\appdata\local\programs\python\python310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.33.1)
# Collecting sniffio>=1.1 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph)
#   Downloading zstandard-0.25.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: certifi in c:\users\huzef\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.4.22)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\huzef\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.13)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.4->langgraph)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic>=2.7.4->langgraph)
#   Downloading pydantic_core-2.46.4-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.7.4->langgraph)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\huzef\appdata\roaming\python\python310\site-packages (from anyio>=3.5.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\huzef\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\huzef\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.6.3)
# Downloading langgraph-1.2.9-py3-none-any.whl (247 kB)
# Downloading langchain_core-1.5.0-py3-none-any.whl (558 kB)
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/558.5 kB ? eta -:--:--
#    ---------------------------------------- 558.5/558.5 kB 120.0 kB/s  0:00:06
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading langsmith-0.10.10-py3-none-any.whl (675 kB)
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    ----------------------------- -------- 524.3/675.2 kB 114.9 kB/s eta 0:00:02
#    ----------------------------- -------- 524.3/675.2 kB 114.9 kB/s eta 0:00:02
#    ----------------------------- -------- 524.3/675.2 kB 114.9 kB/s eta 0:00:02
#    ----------------------------- -------- 524.3/675.2 kB 114.9 kB/s eta 0:00:02
#    ----------------------------- -------- 524.3/675.2 kB 114.9 kB/s eta 0:00:02
#    ----------------------------- -------- 524.3/675.2 kB 114.9 kB/s eta 0:00:02
#    ---------------------------------------- 675.2/675.2 kB 118.0 kB/s  0:00:05
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    ---------- ----------------------------- 0.5/2.1 MB 75.6 kB/s eta 0:00:21
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    --------------- ------------------------ 0.8/2.1 MB 101.4 kB/s eta 0:00:13
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    -------------------- ------------------- 1.0/2.1 MB 96.4 kB/s eta 0:00:11
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------- -------------- 1.3/2.1 MB 100.3 kB/s eta 0:00:08
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ------------------------------ --------- 1.6/2.1 MB 96.2 kB/s eta 0:00:06
#    ----------------------------------- ---- 1.8/2.1 MB 96.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 1.8/2.1 MB 96.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 1.8/2.1 MB 96.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 1.8/2.1 MB 96.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 1.8/2.1 MB 96.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 1.8/2.1 MB 96.1 kB/s eta 0:00:03
#    ----------------------------------- ---- 1.8/2.1 MB 96.1 kB/s eta 0:00:03
#    ---------------------------------------- 2.1/2.1 MB 101.6 kB/s  0:00:20
# Downloading pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.17.0-cp310-cp310-win_amd64.whl (177 kB)
# Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading anyio-4.14.2-py3-none-any.whl (125 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Downloading orjson-3.11.9-cp310-cp310-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp310-cp310-win_amd64.whl (117 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.8.1-cp310-cp310-win_amd64.whl (32 kB)
# Downloading zstandard-0.25.0-cp310-cp310-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, typing-inspection, tenacity, sniffio, pyyaml, pydantic-core, ormsgpack, orjson, langchain-protocol, jsonpointer, h11, distro, annotated-types, requests-toolbelt, pydantic, jsonpatch, httpcore, anyio, httpx, langsmith, langchain-core, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
#
#    -- -------------------------------------  2/28 [websockets]
#    -- -------------------------------------  2/28 [websockets]
#    -- -------------------------------------  2/28 [websockets]
#    -- -------------------------------------  2/28 [websockets]
#    -- -------------------------------------  2/28 [websockets]
#    ------- --------------------------------  5/28 [tenacity]
#    ---------- -----------------------------  7/28 [pyyaml]
#    ---------- -----------------------------  7/28 [pyyaml]
#    ------------ ---------------------------  9/28 [ormsgpack]
#    ------------------ --------------------- 13/28 [h11]
#    -------------------- ------------------- 14/28 [distro]
#    ---------------------- ----------------- 16/28 [requests-toolbelt]
#    ---------------------- ----------------- 16/28 [requests-toolbelt]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------ --------------- 17/28 [pydantic]
#    ------------------------- -------------- 18/28 [jsonpatch]
#    --------------------------- ------------ 19/28 [httpcore]
#    --------------------------- ------------ 19/28 [httpcore]
#    ---------------------------- ----------- 20/28 [anyio]
#    ---------------------------- ----------- 20/28 [anyio]
#    ---------------------------- ----------- 20/28 [anyio]
#    ------------------------------ --------- 21/28 [httpx]
#    ------------------------------ --------- 21/28 [httpx]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    ------------------------------- -------- 22/28 [langsmith]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    -------------------------------- ------- 23/28 [langchain-core]
#    ---------------------------------- ----- 24/28 [langgraph-sdk]
#    ---------------------------------- ----- 24/28 [langgraph-sdk]
#    ---------------------------------- ----- 24/28 [langgraph-sdk]
#    ---------------------------------- ----- 24/28 [langgraph-sdk]
#    ---------------------------------- ----- 24/28 [langgraph-sdk]
#    ----------------------------------- ---- 25/28 [langgraph-checkpoint]
#    ----------------------------------- ---- 25/28 [langgraph-checkpoint]
#    ------------------------------------- -- 26/28 [langgraph-prebuilt]
#    -------------------------------------- - 27/28 [langgraph]
#    -------------------------------------- - 27/28 [langgraph]
#    -------------------------------------- - 27/28 [langgraph]
#    -------------------------------------- - 27/28 [langgraph]
#    -------------------------------------- - 27/28 [langgraph]
#    -------------------------------------- - 27/28 [langgraph]
#    -------------------------------------- - 27/28 [langgraph]
#    -------------------------------------- - 27/28 [langgraph]
#    ---------------------------------------- 28/28 [langgraph]
#
# Successfully installed annotated-types-0.7.0 anyio-4.14.2 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jsonpatch-1.33 jsonpointer-3.1.1 langchain-core-1.5.0 langchain-protocol-0.0.18 langgraph-1.2.9 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 langsmith-0.10.10 orjson-3.11.9 ormsgpack-1.12.2 pydantic-2.13.4 pydantic-core-2.46.4 pyyaml-6.0.3 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 uuid-utils-0.17.0 websockets-15.0.1 xxhash-3.8.1 zstandard-0.25.0
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\huzef\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 from typing import Annotated
#       2 from typing_extensions import TypedDict
# ----> 3 from langgraph.graph import StateGraph, START, END
#       4 from langgraph.graph.message import add_messages
#       5
#
# ModuleNotFoundError: No module named 'langgraph'

# %%
1+1
# Out:
# 2
